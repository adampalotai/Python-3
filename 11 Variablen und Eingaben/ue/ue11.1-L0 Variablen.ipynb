# %% [markdown]
# <div style="background-color:rgba(250,250,250,0.1)">
#
# ---
# # 🐍 `Übungen`:  PRINT mit Variablen
# ---
#
# - Lies dir jede Angabe genau durch, bevor du zu programmieren beginnst.
# - *Deklariere* für JEDE ZAHL und JEDES ZWISCHENERGEBNIS eine Variable mit einem geeigneten Datentyp.
# - Gehe dein Programm im Debug-Modus SCHRITT-für-SCHRITT durch!
# - Vergleiche deine Ausgabe mit der Angabe. Stimmen sie überein?
#
# `Löse alle Aufgaben so, dass die Ausgabe deines Programmes GENAU SO AUSSIEHT wie in der Angabe!`
#
# ---
#
# <div style="text-align: center; background-color: #2f302eff; color: #e6e6e3d8; padding: 8px; border-radius: 6px;">©2026 Prof. Gaisberger</div>
#
# ---
# </div>

# %% [markdown]
# ---
# ### ➡️ *Aufgabe:* Das Rechteck
#
# Ein Rechteck hat eine Länge von 5.4 und eine Breite von 3.2.
# Berechne den Flächeninhalt des Rechtecks und gib das Ergebnis mit <code>print()</code> aus.
#
# *Tipp: Deklariere für Länge, Breite und Fläche eine `Variable` mit einem geeigneten `Datentyp`.*
#
#
# > <div style="background-color:rgba(0, 0, 250, 0.1)">
# >
# > **Erwartete Ausgabe:**
# > ````Text
# >  Die Länge des Rechtecks ist: 5.4
# >  Die Breite des Rechtecks ist: 3.2
# >  Die Fläche des Rechtecks ist: 17.28
# > ````

# %%
# 👉 ---> Dein Code

# %% [markdown]
# <details><summary>💡 Lösung</summary>
#
# ```python
#     # Deklarieren und Initialisieren der Variablen
#     laenge: float = 5.4
#     breite: float = 3.2
#
#     # Berechnen des Ergebnisses
#     flaeche: float = laenge * breite
#
#     # -------------------------------------------------------------
#     # Ausgabe der Variablen
#     print(f"Die Länge des Rechtecks ist: {laenge}")
#     print(f"Die Breite des Rechtecks ist: {breite}")
#     print(f"Die Fläche des Rechtecks ist: {flaeche}")
# ```

# %% [markdown]
# ---
# ### ➡️ *Aufgabe:* Die Prüfung
#
# Ein Schüler hat in den letzten drei Prüfungen folgende Punte erhalten: 85, 90 und 78.
#
# Berechne den Durchschnitt dieser drei Noten und gib das Ergebnis mit <code>print()</code> aus.
#
# > <div style="background-color:rgba(0, 0, 250, 0.1)">
# >
# > **Erwartete Ausgabe:**
# > ````text
# >  Punkte auf erste Prüfung: 85
# >  Punkte auf zweite Prüfung: 90
# >  Punkte auf dritte Prüfung: 78
# >  Der Durchschnitt der Punkte ist: 84.33333333333333
# >  ````

# %%
# 👉 ---> Dein Code

# %% [markdown]
# <details><summary>💡 Lösung</summary>
#
# ```python
#     # Deklarieren und Initialisieren der Variablen
#     punkte1: int = 85
#     punkte2: int = 90
#     punkte3: int = 78
#
#     # Berechnen des Ergebnisses
#     durchschnitt: float = (punkte1 + punkte2 + punkte3) / 3.0
#
#     # -------------------------------------------------------------
#     # Ausgabe der Variablen
#     print(f"Punkte auf erste Prüfung: {punkte1}")
#     print(f"Punkte auf zweite Prüfung: {punkte2}")
#     print(f"Punkte auf dritte Prüfung: {punkte3}")
#     print(f"Der Durchschnitt der Punkte ist: {durchschnitt}")
# ```

# %% [markdown]
# ---
# ### ➡️ *Aufgabe:* Das Auto
#
# Ändere die Ausgabe im folgenden Programm von <code>print()</code> auf <code>print() mit f-Strings</code> um.
# Die Ausgabe soll danach genauso aussehen wie agegeben.
#
# > <div style="background-color:rgba(0, 0, 250, 0.1)">
# >
# > **Erwartete Ausgabe:**
# > ````text
# >   Die maximale Reichweite für einen Audi A5 1.8 TFSI multitronic
# >   mit einer Tankfüllung von 65 Litern beträgt 878.3783783783784 km.
# >
# >   Die Fahrtkosten für 450.0 km betragen 38.06190000000001 Euro.
# >
# >   Nach der Fahrt können noch 428.37837837837844 km zurückgelegt
# >   werden, bis der Tank leer ist.
# > ````

# %%
# Variablen
auto:str              = "Audi A5 1.8 TFSI multitronic"
verbrauch:float       = 7.4   # Liter / 100km 
kraftstoffPreis:float = 1.143 # Euro
fahrStrecke:float     = 450   # km
tankInhalt:int        = 65    # Liter

# Berechnung
kostenProKilometer:float = verbrauch / 100.0 * kraftstoffPreis
kostenFahrstrecke:float  = kostenProKilometer * fahrStrecke
maxReichweite:float      = tankInhalt / verbrauch * 100
restReichweite:float     = maxReichweite - fahrStrecke

# Ausgabe
print("Die maximale Reichweite für einen ", auto )
print("mit einer Tankfüllung von ", tankInhalt )
print(" Litern beträgt ", maxReichweite)
print(" km.")
print("Die Fahrtkosten für ", fahrStrecke ," km betragen ")
print(kostenFahrstrecke , " Euro.")
print("Nach der Fahrt können noch " , restReichweite)
print(" km zurückgelegt werden, bis der Tank leer ist." )

# %% [markdown]
# <details><summary>💡 Lösung</summary>
#
# ```python
#     # Deklarieren und Initialisieren der Variablen
#     auto: str               = "Audi A5 1.8 TFSI multitronic"
#     verbrauch: float        = 7.4
#     kraftstoff_preis: float = 1.143
#     fahrstrecke: float      = 450.0
#     tankinhalt: int         = 65
#
#     # Berechnen der Ergebnisse
#     kosten_pro_kilometer: float = verbrauch / 100 * kraftstoff_preis
#     fahrtkosten: float          = kosten_pro_kilometer * fahrstrecke
#     maximale_reichweite: float  = tankinhalt / verbrauch * 100
#     restreichweite: float       = maximale_reichweite - fahrstrecke
#
#     # Ausgabe der Variablen
#     print(f"Die maximale Reichweite für einen {auto}")
#     print(f"mit einer Tankfüllung von {tankinhalt} Litern beträgt {maximale_reichweite} km.")
#     print()
#     print(f"Die Fahrtkosten für {fahrstrecke} km betragen {fahrtkosten} Euro.")
#     print()
#     print(f"Nach der Fahrt können noch {restreichweite} km zurückgelegt")
#     print("werden, bis der Tank leer ist.")
# ```

# %% [markdown]
# ---
# ### ➡️ *Aufgabe:* Der Wandertag
#
# Deine Klasse geht auf einen Wandertag. Ihr startet um `8 Uhr morgens` und erreicht das Ziel um `12 Uhr mittags`.
# Ihr habt während der Wanderung eine Strecke von `20 Kilometern` zurückgelegt.
#
# Berechne die durchschnittliche Geschwindigkeit der Wandergruppe und gib sie mit <code>print()</code> aus.
# Außerdem trägst du in dein Wanderheft ein, dass der Weg von der Schule bis zum Gipfelpunkt eine Schwierigkeit von `'B'` hatte. Gib die Schwierigkeit des Weges ebenfalls aus.
#
# > <div style="background-color:rgba(0, 0, 250, 0.1)">
# >
# > **Erwartete Ausgabe:**
# > ````text
# >  Die durchschnittliche Geschwindigkeit der Wandergruppe war: 5.0 km/h
# >  Die Schwierigkeit des Weges war: B
# > ````

# %%
# 👉 ---> Dein Code

# %% [markdown]
# <details><summary>💡 Lösung</summary>
#
# ```python
#     # Deklarieren und Initialisieren der Variablen
#     startzeit: int = 8
#     endzeit: int = 12
#     strecke: float = 20.0
#
#     # Berechnen des Ergebnisses
#     zeit: float = endzeit - startzeit
#     geschwindigkeit: float = strecke / zeit
#     schwierigkeit: str = 'B'
#
#     # -------------------------------------------------------------
#     # Ausgabe der Variablen
#     print(f"Die durchschnittliche Geschwindigkeit der Wandergruppe war: {geschwindigkeit} km/h")
#     print(f"Die Schwierigkeit des Weges war: {schwierigkeit}")
# ```

# %% [markdown]
# ---
# ### ➡️ *Aufgabe:* Das Eisverkäufer-Dilemma
#
# Du betreibst einen kleinen Eisladen. Heute hast du 120 Kugeln Eis auf Lager, und jede Kugel kostet 1.5 Euro.
# In den ersten zwei Stunden des Tages verkaufst du 35 Kugeln, und in den nächsten zwei Stunden 50 Kugeln.
#
# Berechne, wie viel Geld du insgesamt eingenommen hast und wie viele Kugeln Eis du noch übrig sind. Gib beides mit <code>print()</code> aus.
#
# > <div style="background-color:rgba(0, 0, 250, 0.1)">
# >
# > **Erwartete Ausgabe:**
# > ````text
# >  Die Gesamteinnahmen betragen: 127.5 Euro
# >  Es sind noch 35 Kugeln Eis übrig.
# > ````

# %%
# 👉 ---> Dein Code

# %% [markdown]
# <details><summary>💡 Lösung</summary>
#
# ```python
#     # Deklarieren und Initialisieren der Variablen
#     kugeln_gesamt: int = 120
#     preis_pro_kugel: float = 1.5
#     verkauf_erste_stunden: int = 35
#     verkauf_zweite_stunden: int = 50
#
#     # Berechnen des Ergebnisses
#     kugeln_verkauft: int = verkauf_erste_stunden + verkauf_zweite_stunden
#     einnahmen: float = kugeln_verkauft * preis_pro_kugel
#     kugeln_uebrig: int = kugeln_gesamt - kugeln_verkauft
#
#     # -------------------------------------------------------------
#     # Ausgabe der Variablen
#     print(f"Die Gesamteinnahmen betragen: {einnahmen} Euro")
#     print(f"Es sind noch {kugeln_uebrig} Kugeln Eis übrig.")
# ```

# %% [markdown]
# ---
# ### ➡️ *Aufgabe:* Die Supermarkt-Kasse
#
# Du arbeitest an einer Supermarkt-Kasse und scannst drei T-Shirts:
# - Zuerst ein T-Schirt mit der Größe 'M' um 5.90 Euro,
# - danach eines um 8.20 mit der Größe 'L' und
# - ein Small T-Shirt um 4.80 Euro
#
# Gib jedes Produkt mit Größe und Preis und den Gesamtbetrag mit <code>print()</code> aus
#
# > <div style="background-color:rgba(0, 0, 250, 0.1)">
# >
# > **Erwartete Ausgabe:**
# > ````text
# >  1. T-Shirt mit Größe M:  5.9 Euro
# >  2. T-Shirt mit Größe L:  8.2 Euro
# >  3. T-Shirt mit Größe S:  4.8 Euro
# >  ---------------------------------
# >  Gesamtbetrag          : 18.9 Euro
# > ````

# %%
# 👉 ---> Dein Code

# %% [markdown]
# <details><summary>💡 Lösung</summary>
#
# ```python
#     # Deklarieren und Initialisieren der Variablen
#     tshirt_1_preis: float = 5.9
#     tshirt_1_groesse: str = 'M'
#     tshirt_2_preis: float = 8.20
#     tshirt_2_groesse: str = 'L'
#     tshirt_3_preis: float = 4.80
#     tshirt_3_groesse: str = 'S'
#
#     # Berechnen des Ergebnisses
#     gesamtbetrag: float = tshirt_1_preis + tshirt_2_preis + tshirt_3_preis
#
#     # -------------------------------------------------------------
#     # Ausgabe der Variablen
#     print(f"1. T-Shirt mit Größe {tshirt_1_groesse}:  {tshirt_1_preis} Euro")
#     print(f"2. T-Shirt mit Größe {tshirt_2_groesse}:  {tshirt_2_preis} Euro")
#     print(f"3. T-Shirt mit Größe {tshirt_3_groesse}:  {tshirt_3_preis} Euro")
#     print("---------------------------------")
#     print(f"Gesamtbetrag          : {gesamtbetrag} Euro")
# ```

# %% [markdown]
# ---
# ### ➡️ *Aufgabe:* Die Obsternte
#
# Auf deinem Hof erntest du heute Obst. Du hast 40 Äpfel und 30 Birnen geerntet. Jede Birne wiegt 0.15 kg und jeder Apfel 0.2 kg.
# Berechne das Gesamtgewicht des geernteten Obstes und gib das Ergebnis aus. Gib außerdem die Anzahl der geernteten Birnen und Äpfel aus.
#
# Finde alle Fehler im Programm und behebe sie. Auch Namenskonventionen, Rechenfehler (Klammern!) und falsche Werte aus der Angabe sind Fehler!
#
# > <div style="background-color:rgba(0, 0, 250, 0.1)">
# >
# > **Erwartete Ausgabe:**
# > ````text
# >  Das Gesamtgewicht des Obstes beträgt: 12.5 kg
# >  Du hast 40 Äpfel und 30 Birnen geerntet.
# > ````

# %%
AnzahlAepfel:int = 40
AnzahlBirnen:str = "30"  # Anzahl der geernteten Birnen

gewicht Apfel = 0,2; int gewicht Birne = 0,15

    # Berechnung des Gesamtgewichts
    gesamtGewicht:str = anzahlÄpfel * gewichtAfpel + anzahlBirne * gew1chtBirn   #Gesamtgewicht aller Früchte

    """Ausgabe der Ergebnisse
    Print("Das Gesamtgewicht des Obstes beträgt: " + gesamtgewicht + ) " kg"
    prin1("Du hast " + anzahlAepfel  Äpfel und "  anzahlBirn + " Birnen geerntet."

# %% [markdown]
# ---
# ### ➡️ *Aufgabe:* Die Kassenabrechnung
#
# Du bist verantwortlich für die Kassenabrechnung eines Tages in einem Café.
# Es wurden 50 Tassen Kaffee für 2.5 Euro pro Tasse und 30 Kuchenstücke für 3 Euro pro Stück verkauft.
# Berechne den Gesamtumsatz und gib den Umsatz für Kaffee und Kuchen separat sowie den Gesamtumsatz auf der Konsole aus.
#
# Finde alle Fehler im Programm und behebe sie. Auch Namenskonventionen, Rechenfehler (Klammern!) und falsche Werte aus der Angabe sind Fehler!
#
# > <div style="background-color:rgba(0, 0, 250, 0.1)">
# >
# > **Erwartete Ausgabe:**
# > ````text
# >  Der Umsatz für Kaffee beträgt: 125.0 Euro
# >  Der Umsatz für Kuchen beträgt: 90.0 Euro
# >  Der gesamte Umsatz beträgt: 215.0 Euro
# > ````

# %%
kaffe-verkauft:int = '50'
preißKaffee:int = "2.75";  Preis pro Tasse Kaffee

kuchenVerkauft:int = 80;
preisKuchen:int = 3,1

    / Berechnung des Umsatzes
    umsatzKaffee:bool = kafeVerkauft + preisskaffee;
    umsatzKuchen:bool = kuchenVerkau1t * preiskuchen;
    gesamtumzatz:bool = umsatsKaffe * umsatzkuchen;

    / Ausgabe der Ergebnisse
    pr1nt("Der Umsatz für Kaffee beträgt: " // + umsazKafee + " Euro")
    pr1nt("Der umsatz für Kuchen beträgt: " + umsatzKuchen +  Euro)
    pr1nt("Der gesamte Umsatz beträgt: "  gesamtumsatz  " Euro)
