# %% [markdown]
# <div style="background-color:rgba(250,250,250,0.1)">
#
# ---
# # ❓ `Fragekatalog:` Variablen
# ---
#
# Arbeite das Arbeitsblatt dazu gründlich durch und beantworte alle Fragen.
#
#
# <div style="text-align: center; background-color: #2f302eff; color: #e6e6e3d8; padding: 8px; border-radius: 6px;">©2026 Prof. Gaisberger</div>
#
# ---
# </div>

# %% [markdown]
# <div style="background-color:rgba(112, 250, 0, 0.1)">
#
# ---
# **Erkläre was eine Variable ist!**<br>
# <br>
# *(Füge hier deine Antwort ein)*<br>
#
#
#
# ---
# </div>

# %% [markdown]
# <div style="background-color:rgba(112, 250, 0, 0.1)">
#
# ---
# **Erkläre, was die Deklaration einer Variable bedeutet!**<br>
# <br>
# *(Füge hier deine Antwort ein)*<br>
#
#
#
# ---
# </div>

# %% [markdown]
# <div style="background-color:rgba(112, 250, 0, 0.1)">
#
# ---
# **Beschreibe, warum die Deklaration einer Variable notwendig ist!**<br>
# <br>
# *(Füge hier deine Antwort ein)*<br>
#
#
#
# ---
# </div>

# %% [markdown]
# <div style="background-color:rgba(112, 250, 0, 0.1)">
#
# ---
# **Erkläre was Initialisieren einer Variablen bedeutet!**<br>
# <br>
# *(Füge hier deine Antwort ein)*<br>
#
#
#
# ---
# </div>

# %% [markdown]
# <div style="background-color:rgba(112, 250, 0, 0.1)">
#
# ---
# **Welche Fehlermeldung wird ausgegeben, wenn eine Variable nicht deklariert ist?**<br>
# <br>
# *(Füge hier deine Antwort ein)*<br>
#
#
#
# ---
# </div>

# %% [markdown]
# <div style="background-color:rgba(112, 250, 0, 0.1)">
#
# ---
# **Erkläre was Namenskonventionen sind!**<br>
# <br>
# *(Füge hier deine Antwort ein)*<br>
#
#
#
# ---
# </div>

# %% [markdown]
# <div style="background-color:rgba(112, 250, 0, 0.1)">
#
# ---
# **Nenne die Regeln, welche für die Schreibweise von Variablennamen gelten!**<br>
# <br>
# *(Füge hier deine Antwort ein)*<br>
#
#
#
# ---
# </div>

# %% [markdown]
# <div style="background-color:rgba(112, 250, 0, 0.1)">
#
# ---
# **Zähle die Zeichen auf, welche in einem Variablennamen verwendet werden dürfen!**<br>
# <br>
# *(Füge hier deine Antwort ein)*<br>
#
#
#
# ---
# </div>

# %% [markdown]
# <div style="background-color:rgba(112, 250, 0, 0.1)">
#
# ---
# **Zähle die Zeichen auf, welche in einem Variablennamen NICHT verwendet werden dürfen!**<br>
# <br>
# *(Füge hier deine Antwort ein)*<br>
#
#
#
# ---
# </div>

# %% [markdown]
# <div style="background-color:rgba(112, 250, 0, 0.1)">
#
# ---
# **Beschreibe, worauf du beim Zuweisen eines Wertes zu einer Variable achten musst!**<br>
# <br>
# *(Füge hier deine Antwort ein)*<br>
#
#
#
# ---
# </div>

# %% [markdown]
# <div style="background-color:rgba(112, 250, 0, 0.1)">
#
# ---
# Was eine Variable enthalten kann wird bei ihrer Deklaration angegeben.
# **Beschreibe, welche Art von Daten folgende Variable enthalten kann!**<br>
# **Initialisiere sie weiters mit einem geeigneten Wert!**<br>
# ````python
#     eineVariable: int
# ````
# <br>
#
# *(Füge hier deine Antwort ein)* <br>
#
#
#
# ---
# </div>
