# %% [markdown]
# <div style="background-color:rgba(250,250,250,0.1)">
#
# ---
# # 🐍 `Übungen`:  PRINT mit f-Strings
# ---
#
# - Lies dir jede Angabe genau durch, bevor du zu programmieren beginnst.
# - *Deklariere* für JEDE ZAHL und JEDES ZWISCHENERGEBNIS eine Variable mit einem geeigneten Datentyp.
# - Gehe dein Programm im Debug-Modus SCHRITT-für-SCHRITT durch!
# - Vergleiche deine Ausgabe mit der Angabe. Stimmen sie überein?
#
# `Löse alle Aufgaben so, dass die Ausgabe deines Programmes GENAU SO AUSSIEHT wie in der Angabe!`
#
# ---
#
# <div style="text-align: center; background-color: #2f302eff; color: #e6e6e3d8; padding: 8px; border-radius: 6px;">©2026 Prof. Gaisberger</div>
#
# ---
# </div>

# %% [markdown]
# ---
# ### ➡️ Aufgabe: Terminanzeige
# Frage Wochentag, Tag, Monat, Jahr, Stunde und Minute ab und gib sie formatiert als Terminüberschrift aus.<br>
# Dabei gilt: Tage, Monate, Stunden und Minuten werden immer zweistellig mit führender 0 ausgegeben.
#
# ``` Text
#     *** Montag,  08.07.2025 - 14:05 Uhr ***
# ```

# %%
# 👉 ---> Dein Code

# %% [markdown]
# ---
# ### ➡️ Aufgabe: Tabellenzeile
# Frage Name, Punkte und Note ab. Gib eine sauber ausgerichtete Tabelle aus:<br>
# Punkte werden rechtsbündig und die Note zentriert ausgegeben.
#
# ```` Text
#     ┌────────────────┬────────┬─────────┐
#     │ Name           │ Punkte │ Note    │
#     ├────────────────┼────────┼─────────┤
#     │ Max Muster     │     93 │    1    │
#     └────────────────┴────────┴─────────┘
# ````

# %%
# 👉 ---> Dein Code

# %% [markdown]
# ---
# ### ➡️ Aufgabe: Kontoauszug
# Frage Betrag, Empfänger und IBAN ab. Gib den Eintrag als zentrierte Buchungszeile aus:
#
# ```` Text
#     +++      Überweisung an MAX MUSTER (DE1234567890) über 350.00€        +++
# ````

# %%
# 👉 ---> Dein Code

# %% [markdown]
# ---
# ### ➡️ Aufgabe: Bestellübersicht
# Frage Produktname, Stückzahl, Einzelpreis und berechne den Gesamtpreis. Gib die Daten übersichtlich formatiert aus:
#
# ```` Text
#     ┌───────────────────┬───────────┬─────────────────────┬─────────────────┐
#     │ Produkt: Tastatur | Menge:  3 | Einzelpreis: 29.99€ | Gesamt:  89.97€ |
#     └───────────────────┴───────────┴─────────────────────┴─────────────────┘
# ````

# %%
# 👉 ---> Dein Code

# %% [markdown]
# ---
# ### ➡️ Aufgabe: Flächenberechnung eines Rechtecks
#
# Frage den Benutzer nach der **Länge** und der **Fläche** eines Rechtecks (als Kommazahlen).
# Berechne daraus
# - die **Breite** und
# - den **Umfang**.
#
# Gib alle Zahlen immer `6-stellig, rechtsbündig mit 2 Nachkommastellen` aus:
#
# ``` Text
#     Geben sie bitte die Länge ein: 5.5
#     Geben sie bitte die Fläche ein: 17.6
#
#     ┌────────┬────────────┐
#     │ Länge  │    5.50 m  │
#     │ Breite │    3.20 m  │
#     ├────────┼────────────┤
#     │ Umfang │   17.40 m  │
#     │ Fläche │   17.60 m² │
#     └────────┴────────────┘
#
# ```

# %%
# 👉 ---> Dein Code

# %% [markdown]
# ---
# ### ➡️ Aufgabe: Geburtstagsanzeige
#
# Frage den Benutzer nach seinem **Namen** und **Geburtstag** (z. B. 12.07.). <br>
# Frag ihn weiters nach der Anzahl der Party-Emojis.<br>
# Gib eine nette Geburtstagsnachricht mit der gewünschten Anzahl von Emojis aus, z. B. mit 7 Emojis:
#
# *Tipp: Wiederhole das Zeichen mit 🎉 mit `*`*
#
# ```Text
#     Alles Gute zum Geburtstag, Mia! 🎉🎉🎉🎉🎉🎉🎉
#     Wir hoffen, du feierst 🎉 schön am 12.07.!
# ```

# %%
# 👉 ---> Dein Code

# %% [markdown]
# ---
# ### ➡️ Aufgabe: Spritrechner
#
# Frage:
# - Gefahrene Strecke (in km, float)
# - Durchschnittsverbrauch (in Liter pro 100 km)
# - Preis pro Liter (in Euro)
#
# Berechne:
# - Gesamtkosten
#
# Beispiel:
# ``` Text
#      Kosten für die Fahrt: 21.78 €
# ```

# %%
# 👉 ---> Dein Code

# %% [markdown]
# ---
# ### ➡️ Aufgabe: Notendurchschnitt
#
# Frage den Benutzer nach **drei Schulnoten** (ganzzahlig) und berechne den **Durchschnitt**.
# Gib das Ergebnis mit 2 Nachkommastellen aus.
#
# Beispiel:
# ```Text
#     Durchschnitt: 2.33
# ```

# %%
# 👉 ---> Dein Code

# %% [markdown]
# ---
# ### ➡️ Aufgabe: T-Shirt-Bestellung
#
# Frage:
# - Anzahl T-Shirts
# - Preis pro T-Shirt (z. B. 14.99)
# - Name des Käufers
#
# Gib eine Rechnung in folgender Form aus:
#
# *Tipp für die Mehrwertsteuer (MwSt):* Der Gesamtpreis enthält bereits 20% MwSt. Du kannst den MwSt-Anteil mit der Formel `gesamtpreis * 20 / 120` berechnen.
#
# ``` Text
#     Dein Name: Lara
#     Wie viele T-Shirts: 3
#     Einzelpreis des T-Shirts: 14.99
#
#     ┌─────────────────────────────────┐
#     │ Rechnung für: Lara              │
#     ├────────────────────┬────────────┤
#     │ Preis pro T-Shirt  │    14.99 € │
#     │ Anzahl             │        3   │
#     ├────────────────────┼────────────┤
#     │ Gesamt             │    44.97 € │
#     │ inkl. 20% MwSt     │     7.49 € │
#     └────────────────────┴────────────┘
# ```

# %%
# 👉 ---> Dein Code

# %% [markdown]
# ---
# ### ➡️ Aufgabe: Minutenrechner
#
# Ein Benutzer gibt eine Anzahl **Tage** ein. Das Programm berechnet und gibt aus:
# - die Anzahl Stunden
# - die Anzahl Minuten
# - die Anzahl Sekunden
#
# Gib alle Werte 5-stellig und mit einer Nachkommstelle aus.
#
# Erweiterung: Frage zusätzlich den Namen des Benutzers ab und begrüße ihn persönlich.

# %%
# 👉 ---> Dein Code
