# %% [markdown]
# <div style="background-color:rgba(250,250,250,0.1)">
#
# ---
# # ❓ `Fragekatalog:` Erste Schritte
# ---
#
# Arbeite das Arbeitsblatt dazu gründlich durch und beantworte alle Fragen.
#
#
# <div style="text-align: center; background-color: #2f302eff; color: #e6e6e3d8; padding: 8px; border-radius: 6px;">©2026 Prof. Gaisberger</div>
#
# ---
# </div>

# %% [markdown]
# <div style="background-color:rgba(112, 250, 0, 0.1)">
#
# ---
# **Erkläre was eine Anweisung ist!**<br>
# <br>
# *(Füge hier deine Antwort ein)*<br>
#
#
#
# ---
# </div>

# %% [markdown]
# <div style="background-color:rgba(112, 250, 0, 0.1)">
#
# ---
# **Erkläre was ein Programm ist!**<br>
# <br>
# *(Füge hier deine Antwort ein)*<br>
#
#
#
# ---
# </div>

# %% [markdown]
# <div style="background-color:rgba(112, 250, 0, 0.1)">
#
# ---
# **Erkläre was ein Parameter ist!**<br>
# <br>
# *(Füge hier deine Antwort ein)*<br>
#
#
#
# ---
# </div>

# %% [markdown]
# <div style="background-color:rgba(112, 250, 0, 0.1)">
#
# ---
# **Erkläre was ein Kommentar ist! Warum wird er benötigt?**<br>
# <br>
# *(Füge hier deine Antwort ein)*<br>
#
#
#
# ---
# </div>

# %% [markdown]
# <div style="background-color:rgba(112, 250, 0, 0.1)">
#
# ---
# **Erkläre den Unterschied zwischen einzeiligen und mehrzeiligen Kommentaren! Gib jeweils die korrekte Schreibweise und ein Beispiel an.**<br>
# <br>
# *(Füge hier deine Antwort ein)*<br>
#
#
#
# ---
# </div>

# %% [markdown]
# <div style="background-color:rgba(112, 250, 0, 0.1)">
#
# ---
# **Erkläre den Unterschied zwischen einem Kommentar und einer Anweisung!**<br>
# <br>
# *(Füge hier deine Antwort ein)*<br>
#
#
#
# ---
# </div>

# %% [markdown]
# <div style="background-color:rgba(112, 250, 0, 0.1)">
#
# ---
# **Erkläre, was man unter der Syntax einer Programmiersprache versteht!**<br>
# <br>
# *(Füge hier deine Antwort ein)*<br>
#
#
#
# ---
# </div>

# %% [markdown]
# <div style="background-color:rgba(112, 250, 0, 0.1)">
#
# ---
# **Erkläre wodurch ein Syntaxfehler entsteht und gib dazu ein Beispiel!**<br>
# <br>
# *(Füge hier deine Antwort ein)*<br>
#
#
#
# ---
# </div>

# %% [markdown]
# <div style="background-color:rgba(112, 250, 0, 0.1)">
#
# ---
# **Erkläre, was man unter der Semantik in einer Programmiersprache versteht!**<br>
# <br>
# *(Füge hier deine Antwort ein)*<br>
#
#
#
# ---
# </div>

# %% [markdown]
# <div style="background-color:rgba(112, 250, 0, 0.1)">
#
# ---
# **Erkläre was eine Modulo-Rechnung ist! Gib auch das dafür benötigte Zeichen und eine Modulo-Rechnung an**<br>
# <br>
# *(Füge hier deine Antwort ein)*<br>
#
#
#
# ---
# </div>

# %% [markdown]
# <div style="background-color:rgba(112, 250, 0, 0.1)">
#
# ---
# **Gib ein Beispiel wofür man eine Modulo-Rechnung verwenden kann an!**<br>
# <br>
# *(Füge hier deine Antwort ein)*<br>
#
#
#
# ---
# </div>
