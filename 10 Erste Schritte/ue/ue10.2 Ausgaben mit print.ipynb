# %% [markdown]
# <div style="background-color:rgba(250,250,250,0.1)">
#
# ---
# # 🐍 `Übungen`:  PRINT() - Erste Schritte
# ---
#
# - Lies dir jede Angabe genau durch, bevor du zu programmieren beginnst.
# - Gehe dein Programm im Debug-Modus SCHRITT-für-SCHRITT durch!
# - Vergleiche deine Ausgabe mit der Angabe. Stimmen sie überein?
#
# `Löse alle Aufgaben so, dass die Ausgabe deines Programmes GENAU SO AUSSIEHT wie in der Angabe!`
#
# ---
#
# <div style="text-align: center; background-color: #2f302eff; color: #e6e6e3d8; padding: 8px; border-radius: 6px;">©2026 Prof. Gaisberger</div>
#
# ---
# </div>

# %% [markdown]
# ---
# ### ➡️ *Aufgabe:* Erstelle deine Visitenkarte
#
# Gib die folgenden Angaben jeweils in einer eigenen Zeile aus.
#
# - Vor- und Nachname
# - Adresse
# - Geburtsdatum
# - Lieblingsfach
# - Hobbys
# - Lieblingsband
# - Namen der Eltern und Geschwister oder besten Freundinnen bzw. Freunde
#
# Gib jede Information mit `print` aus.

# %%
# 👉 ---> Dein Code

# %% [markdown]
# ---
# ### ➡️ *Aufgabe:* Umrande deine Visitenkarte
#
# Erweitere die Visitenkarte in der vorherigen Aufgabe um einen Rahmen.
#
# ```text
#     --------------------------------------------
#     | Vorname Nachname                         |
#     | Adresse                                  |
#     | Geburtsdatum                             |
#     | Lieblingsfach                            |
#     | ...                                      |
#     --------------------------------------------
# ```

# %%
# 👉 ---> Dein Code

# %% [markdown]
# ---
# ### ➡️ *Aufgabe:* Gib diese Flagge aus
#
# Gib diese Flagge aus. Verwende für jede Zeile ein `print()`.
#
# *Beachte: In jeder zweiten Zeile sind die Sterne verschoben!*
#
#
# ```text
# * * * * * * ==================================
#  * * * * *  ==================================
# * * * * * * ==================================
#  * * * * *  ==================================
# * * * * * * ==================================
#  * * * * *  ==================================
# * * * * * * ==================================
#  * * * * *  ==================================
# * * * * * * ==================================
# ==============================================
# ==============================================
# ==============================================
# ==============================================
# ==============================================
# ==============================================
# ```

# %%
# 👉 ---> Dein Code

# %% [markdown]
# ---
# ### ➡️ *Aufgabe:* Addiere 4 Zahlen
#
# Schreibe eine <code>print()</code> Anweisung, welche
# - die Zahlen 56, 89, 5, 123 addiert und
# - die Summe ausgibt!
# <br>
#
# > <div style="background-color:rgba(0, 0, 250, 0.1)">
# >
# > **Erwartete Ausgabe:**
# > ````text
# >   56 + 89 + 5 + 123 = 273
# > ````

# %%
# 👉 ---> Dein Code

# %% [markdown]
# <details><summary>💡 Lösung</summary>
#
# ```python
#     # Es gibt mehrere Möglichkeiten, die du bereits kennst
#     # 1. Lösung
#     print("56 + 89 + 5 + 123 =", end=" ")    # Gibt die Rechnung als Text aus (die Rechnung steht zwischen Hochkomma !!)
#     print(567+ 89 + 5 + 123)                 # Berechnet die Summe und gibt sie aus
#
#     # 2. Lösung
#     # Zuerst die Rechnung als Text ausgeben und dann das Ergebnis
#     print("567+ 89 + 5 + 123 =", 567+ 89 + 5 + 123)
#
# ```
# </details>

# %% [markdown]
# ---
# ### ➡️ *Aufgabe:* Multipliziere 3 Zahlen
#
# Schreibe eine <code>print()</code> Anweisung, welche
# - die Zahlen 15.6, 7.89, 0.678 multipliziert und
# - ihr Produkt ausgibt!
# <br>
#
# > <div style="background-color:rgba(0, 0, 250, 0.1)">
# >
# > **Erwartete Ausgabe:**
# > ````text
# >   15.6 * 7.89 * 0.678 = 83.450952
# > ````

# %%
# 👉 ---> Dein Code

# %% [markdown]
# ---
# ### ➡️ *Aufgabe:* Addiere 4 Kommazahlen
#
# Schreibe eine <code>print()</code> Anweisung, welche
# - die Zahlen 45.67, 12.56, -23.5, 87.56 addiert und
# - die Summe ausgibt!
# <br>
#
# > <div style="background-color:rgba(0, 0, 250, 0.1)">
# >
# > **Erwartete Ausgabe:**
# > ````text
# >   45,67 + 12,56 + -23,5 + 87,56 = 122,29
# > ````

# %%
# 👉 ---> Dein Code

# %% [markdown]
# ---
# ### ➡️ *Aufgabe:* Berechne folgende Formel
#
# Schreibe eine <code>print()</code> Anweisung, welche folgende Formel berechnet und das Ergebnis ausgibt.
#
# - 4.0 * (1 - (1.0/3) + (1.0/5) - (1.0/7) + (1.0/9) - (1.0/11))
#
# <br>
#
# > <div style="background-color:rgba(0, 0, 250, 0.1)">
# >
# > **Erwartete Ausgabe:**
# > ````text
# >   Ergebnis der Formel = 2.976046
# > ````

# %%
# 👉 ---> Dein Code
