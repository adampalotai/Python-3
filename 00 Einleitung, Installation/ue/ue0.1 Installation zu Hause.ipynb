# %% [markdown]
# <div style="background-color:rgba(250,250,250,0.1)">
#
# ---
# # 🏡 Installation zu Hause
# ---
#
# Nachdem du VSCode und Python erfolgreich installiert hast, wollen wir
#
# - `testen` → ob die Programme wirklich funktionieren
# - `üben` → wie man einen Screenshot erstellt und einfügt und
# - `üben` → wie man eine Übung abgibt
#
# ---
# <div style="text-align: center; background-color: #2f302eff; color: #e6e6e3d8; padding: 8px; border-radius: 6px;">©2026 Prof. Gaisberger</div>
#
# ---
# </div>

# %% [markdown]
# ---
# ## `Aufgabe 1:` Teste, ob VSCode funktioniert
#
# Führe dazu alle Tests weiter unten durch.

# %% [markdown]
# <div style="background-color:rgba(250, 250, 250, 0.1)">
#
# ---
#
# Damit VS-Code weiß, dass du Python-Programme ausführen möchtest, musst du zuvor einen `KERNEL` auswählen (Rechts oben)
#
# ![image.png](attachment:image.png)
#
#  ---
# ![image-4.png](attachment:image-4.png)
#
#  ---
# ![image-3.png](attachment:image-3.png)
#
# Nun kannst du jeden Test mit ausführen! Klicke dazu in jeden Block und drücke den **Ausführen Button**
#
# ![image-5.png](attachment:image-5.png)
#
#
# ---
# </div>

# %%
""" --------------------------------------------------------
Test: Hello World
--------------------------------------------------------"""
# Gibt einen einfachen Text aus
print("Hello, World!")

# %%
""" --------------------------------------------------------
Test: Bibliothek math importieren
--------------------------------------------------------"""
import math

# Berechnet die Wurzel von 16 und gibt den Wert von Pi aus
print("Wurzel aus 16:", math.sqrt(16))
print("Pi:", math.pi)

# %%
""" --------------------------------------------------------
Test: Bibliothek random importieren
--------------------------------------------------------"""
import random

# Generiert eine Zufallszahl zwischen 1 und 10
zufallszahl = random.randint(1, 10)
print("Zufallszahl zwischen 1 und 10:", zufallszahl)

# %% [markdown]
# ---
# ### Eingaben für das Programm
# Musst du etwas eingeben, öffnet sich in der Titelleiste eine Aufforderung. Gib die Zahl ein und bestätige mit ENTER.
#
# ![image-2.png](attachment:image-2.png)

# %%
""" --------------------------------------------------------
Test: Eingabe einer Zahl
--------------------------------------------------------"""
# Fragt eine Zahl ab und gibt sie wieder aus
zahl = float(input("Bitte gib eine Zahl ein: "))
print("Du hast folgende Zahl eingegeben:", zahl)

# %% [markdown]
# ---
#
# ## `Aufgabe 2:` Füge einen Screenshot ein
#
# - Starte VSCode,
# - verschiebe das Fenster von VSCode so, dass man einen Teil deines Dekstops sehen kann,
# - erstelle einen Screenshot auf dem dein Desktop UND VSCode mit diesem Arbeitsblatt zu sehen ist und
# - füge diesen Screenshot hier ein!

# %% [markdown]
# (*Markiere diesen Text und ersetze ihn durch deinen Bildschirmausschnitt.*)

# %% [markdown]
# <div style="background-color:rgba(250, 250, 250, 0.1)">
#
# ---
#
# ##### ✨ Merke:
#
#
# Einen Bildschirmausschnitt kannst du mit den Tasten
#
# - `Windows-Shift S`
#
# erstellen.
#
# ---
# </div>

# %% [markdown]
# ---
#
# ## `Aufgabe 3:` Gib die Übung in Teams ab
